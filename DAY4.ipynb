# %%
l=[]
print(l)
print(type(l))
# Out:
# []
# <class 'list'>

# %%
l=[1,2,3,4,5,6]
print(l)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l.append(7)
print(7)
# Out:
# 7

# %%
l.insert(1,8)
print(l)
# Out:
# [1, 8, 2, 3, 4, 5, 6, 7]

# %%
l.pop()
print(l)
# Out:
# [1, 8, 2, 3, 4, 5, 6]

# %%
l.pop(1)
print(l)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l.remove(5)
print(l)
# Out:
# [1, 2, 3, 4, 6]

# %%
l1=[1,2,3]
l2=[4,5,6]
l1.append(l2)
print(l1)
# Out:
# [1, 2, 3, [4, 5, 6]]

# %%
l=[1,6,9,3,8]
l.sort()
print(l)
# Out:
# [1, 3, 6, 8, 9]

# %%
l.reverse()
print(l)
# Out:
# [9, 8, 6, 3, 1]

# %%
d={}
print(d)
print(type(d))
# Out:
# {}
# <class 'dict'>

# %%
d={'name':'sriya','city':'KKD'}
print(d)
# Out:
# {'name': 'sriya', 'city': 'KKD'}

# %%
print(d["name"])
# Out:
# sriya

# %%
d["mobile no"]=9398133482
print(d)
# Out:
# {'name': 'sriya', 'city': 'KKD', 'mobile no': 9398133482}

# %%
print(d.keys())
# Out:
# dict_keys(['name', 'city', 'mobile no'])

# %%
print(d.values())
# Out:
# dict_values(['sriya', 'KKD', 9398133482])

# %%
print(d.items())
# Out:
# dict_items([('name', 'sriya'), ('city', 'KKD'), ('mobile no', 9398133482)])

# %%
f=open('abc.txt','w')
print('File name:',f.name)
print('File Mode:',f.mode)
print(f.readable())
print(f.writable())
print(f.closed)
f.close()
print(f.closed)
# Out:
# File name: abc.txt
# File Mode: w
# False
# True
# False
# True

# %%
with open("abc.txt","r") as file:
    content=file.read()
print(content)
# Out:
# Aditya Degree College
# Kakinada
# Andhra Pradesh

# %%
with open("abc.txt","r") as file:
    content=file.read(10)
print(content)
# Out:
# Aditya Deg

# %%
with open("abc.txt","r") as file:
    content=file.readline()
print(content)
# Out:
# Aditya Degree College

# %%
with open("abc.txt","r") as file:
    content=file.readlines()
print(content)
# Out:
# ['Aditya Degree College\n', 'Kakinada\n', 'Andhra Pradesh']

# %%
with open("abc.txt","w")as file:
    file.write("Aditya Degree College")

# %%
l=["Aditya Degree College\n","Kakinada\n","Andhra Pradesh\n"]
with open("abc.txt","w")as file:
  file.writelines(l)

# %%
with open("abc.txt","a")as file:
    file.write("533003")
